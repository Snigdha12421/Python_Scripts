# %%
import pandas as pd

data = {
    "Name": ["Rohit", "Sneha", "Aman", "Priya", "Kiran"],
    "Roll_No": [101, 102, 103, 104, 105],
    "Branch": ["CSE", "IT", "ECE", "CSE", "ME"],
    "Semester": [3, 5, 1, 7, 2],
    "Marks": [85, 92, 76, 88, 90]
}

df = pd.DataFrame(data)

df.to_csv("student_data.csv", index=False)

print("Content of CSV file:\n")
print(pd.read_csv("student_data.csv"))
# Out:
# Content of CSV file:
#
#     Name  Roll_No Branch  Semester  Marks
# 0  Rohit      101    CSE         3     85
# 1  Sneha      102     IT         5     92
# 2   Aman      103    ECE         1     76
# 3  Priya      104    CSE         7     88
# 4  Kiran      105     ME         2     90
